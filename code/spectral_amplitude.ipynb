# %%
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt

# %%
f = h5.File("NS2D_amplitude.h5")

# %%
U = f["Amplitude/1"][:, :, :, :]

# %%
U.shape
# Out:
# (2, 4, 64, 1000)

# %%
c = plt.contourf(U[1, :, :, 999], levels=30)
plt.colorbar(c)

# %%
plt.plot(U[1, :, 16, 100])

# %%
U[1, 3, 16, 0]
# Out:
# -0.000980171704416318

# %%
f.close()

# %%
from spectralDNS import config

# %%
m =
# Out:
#   Cell In[10], line 1
#     m =
#         ^
# SyntaxError: invalid syntax
