# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File("NS2D_w.h5")

# %%
U = np.array([f["U0/2D/1000"], f["U1/2D/100"]])

# %%
U.shape
# Out:
# (2, 128, 128)

# %%
x = plt.contourf(U[1])
plt.colorbar(x)

# %%
P = np.array(f["P/2D/1000"])

# %%
plt.contourf(P)
